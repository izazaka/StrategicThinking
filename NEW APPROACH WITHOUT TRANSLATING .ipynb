# %%
import pandas as pd

import pandas as pd

import numpy as np

import matplotlib as mpl

import matplotlib.pyplot as plt

import seaborn as sns 

sns.set(color_codes = True)

import statistics as stats

# %matplotlib inline

from scipy.stats import binom

from scipy.stats import poisson

from scipy.stats import norm

import scipy.stats as ss

# %%
pip install emoji
# Out:
# Requirement already satisfied: emoji in /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages (2.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
f = pd.read_csv("file209.csv")

# %%
f.head()
# Out:
#                                        reviewer starRating  \
# 0    {'displayName': 'Alessandro Filipe (Alê)'}       FIVE
# 1           {'displayName': 'Rilvana Pinheiro'}       FIVE
# 2            {'displayName': 'Renata Vallerio'}       FOUR
# 3              {'displayName': 'Luis Fernando'}       FIVE
# 4  {'displayName': 'Ana Paula Beltrão Machado'}       FIVE
#
#                                              comment  \
# 0  (Translated by Google) Camping is pretty cool\...
# 1  (Translated by Google) Wonderful place to spen...
# 2                                                 Ok
# 3  (Translated by Google) Wonderful space and exp...
# 4  (Translated by Google) It's great for taking c...
#
#                  createTime                updateTime  \
# 0  2017-08-02T01:33:16.793Z  2017-08-02T01:33:16.793Z
# 1  2017-07-31T22:03:13.250Z  2017-07-31T22:03:13.250Z
# 2  2017-07-30T20:02:42.772Z  2017-07-30T20:02:42.772Z
# 3  2017-07-29T11:41:13.472Z  2017-07-29T11:41:40.938Z
# 4  2017-07-29T03:58:47.007Z  2017-07-29T04:00:17.528Z
#
#                                                 name  \
# 0  accounts/113838515205835963900/locations/41527...
# 1  accounts/113838515205835963900/locations/41527...
# 2  accounts/113838515205835963900/locations/41527...
# 3  accounts/113838515205835963900/locations/41527...
# 4  accounts/113838515205835963900/locations/41527...
#
#                  displayName              reviewer_name  \
# 0    Alessandro Filipe (Alê)    Alessandro Filipe (Alê)
# 1           Rilvana Pinheiro           Rilvana Pinheiro
# 2            Renata Vallerio            Renata Vallerio
# 3              Luis Fernando              Luis Fernando
# 4  Ana Paula Beltrão Machado  Ana Paula Beltrão Machado
#
#                               review_id reviewReply
# 0   ChZDSUhNMG9nS0VJQ0FnSURRekxMMFhnEAE         NaN
# 1   ChZDSUhNMG9nS0VJQ0FnSUNBMXBEOURnEAE         NaN
# 2  ChdDSUhNMG9nS0VJQ0FnSURBb3NHM25BRRAB         NaN
# 3  ChdDSUhNMG9nS0VJQ0FnSURnMzc2a2t3RRAB         NaN
# 4   ChZDSUhNMG9nS0VJQ0FnSUNRbUpXbUx3EAE         NaN

# %% [markdown]
# import pandas as pd
#
# # Your DataFrame with a 'comment' column
# data = f["comment"]
# df = pd.DataFrame(data)
#
# # Extract the text before and after "(Original)"
# split_df = df['comment'].str.split('(Original)', expand=True, n=1)
# df['before_original'] = split_df[0]
# df['after_original'] = split_df[1]
#
# # Display the DataFrame with new columns
# print(df[['comment', 'before_original', 'after_original']])

# %% [markdown]
# df["before_original"]

# %% [markdown]
# df["before_original"].loc[3]

# %% [markdown]
# df["before_original"].loc[30]

# %% [markdown]
# df["after_original"].loc[30]

# %% [markdown]
# text_before_original = df["before_original"].loc[30]
# print(text_before_original)

# %% [markdown]
# text_before_original = df["before_original"].loc[60]
# print(text_before_original)

# %% [markdown]
# f["comment"].loc[60]

# %% [markdown]
# f["comment"].loc[3]

# %%
f["starRating"].unique()
# Out:
# array(['FIVE', 'FOUR', 'TWO', 'ONE', 'THREE'], dtype=object)

# %%
f["starRating"].replace('ONE', 1, inplace = True)
f["starRating"].replace('TWO', 2, inplace = True)
f["starRating"].replace('THREE', 3, inplace = True)
f["starRating"].replace('FOUR', 4, inplace = True)
f["starRating"].replace('FIVE', 5, inplace = True)

# %%
import pandas as pd

# Assuming your DataFrame is named 'f' with a 'comment' column
f['comment'] = f['comment'].astype(str)  # Ensure the 'comment' column is of string type

# Extract the text before and after "(Original)"
split_df = f['comment'].str.split('(Original)', expand=True, n=1)
f['before_original'] = split_df[0]
f['after_original'] = split_df[1]

# Display the DataFrame with new columns
#print(f[['comment', 'before_original', 'after_original']])

# %%
f.tail()
# Out:
#                                        reviewer  starRating  \
# 263    {'displayName': 'Cleber Gerber Mangini'}           5
# 264             {'displayName': 'Rosa Ferrari'}           5
# 265           {'displayName': 'Isabella Catto'}           5
# 266  {'displayName': 'Marilda Fatima da Silva'}           5
# 267         {'displayName': 'Giovanna Sanchez'}           5
#
#                                                comment  \
# 263                                                nan
# 264  (Translated by Google) I really enjoyed this p...
# 265                                                nan
# 266                                                nan
# 267                                                nan
#
#                       createTime                   updateTime  \
# 263  2018-11-16T23:07:01.174991Z  2018-11-16T23:07:01.174991Z
# 264  2018-11-16T21:20:03.059487Z  2018-11-16T21:20:03.059487Z
# 265  2018-11-16T21:12:33.298498Z  2018-11-16T21:12:33.298498Z
# 266  2018-11-16T20:32:39.223279Z  2018-11-16T20:32:39.223279Z
# 267  2018-11-15T20:19:37.060735Z  2018-11-15T20:19:37.060735Z
#
#                                                   name  \
# 263  accounts/113838515205835963900/locations/41527...
# 264  accounts/113838515205835963900/locations/41527...
# 265  accounts/113838515205835963900/locations/41527...
# 266  accounts/113838515205835963900/locations/41527...
# 267  accounts/113838515205835963900/locations/41527...
#
#                  displayName            reviewer_name  \
# 263    Cleber Gerber Mangini    Cleber Gerber Mangini
# 264             Rosa Ferrari             Rosa Ferrari
# 265           Isabella Catto           Isabella Catto
# 266  Marilda Fatima da Silva  Marilda Fatima da Silva
# 267         Giovanna Sanchez         Giovanna Sanchez
#
#                                 review_id reviewReply  \
# 263   ChZDSUhNMG9nS0VJQ0FnSUNJbnZtcUh3EAE         NaN
# 264   ChZDSUhNMG9nS0VJQ0FnSUNvNmQtRVl3EAE         NaN
# 265  ChdDSUhNMG9nS0VJQ0FnSUNJbnQ3anZ3RRAB         NaN
# 266   ChZDSUhNMG9nS0VJQ0FnSUNJbnZia0pREAE         NaN
# 267  ChdDSUhNMG9nS0VJQ0FnSUNJcnRISHd3RRAB         NaN
#
#                                        before_original after_original
# 263                                                nan           None
# 264  (Translated by Google) I really enjoyed this p...       Original
# 265                                                nan           None
# 266                                                nan           None
# 267                                                nan           None

# %%
import pandas as pd

# Assuming you have a DataFrame named 'f' with a column named 'comment'
# Replace the sample data with your actual DataFrame

# Function to clean the text
def clean_text(text):
    if pd.notna(text):  # Check for NaN values
        # Remove "(Translated by Google)"
        text = text.replace('(Translated by Google)', '')

        # Remove "\n\n(Original)\n"
        text = text.replace('\n\n(Original)\n', '')
        
        # Remove "\n\n(Original)\n"
        text = text.replace('\n\n', '')
        
        # Remove "\n\n(Original)\n"
        text = text.replace('(', '')

        # Remove "\" 
        text = text.replace('\\', '')

        return text.strip()  # Remove leading and trailing whitespaces
    else:
        return text  # Return NaN if the input is NaN

# Apply the cleaning function to each row in the 'comment' column
f['cleaned_text'] = f['before_original'].apply(clean_text)

# %%
f.head()
# Out:
#                                        reviewer  starRating  \
# 0    {'displayName': 'Alessandro Filipe (Alê)'}           5
# 1           {'displayName': 'Rilvana Pinheiro'}           5
# 2            {'displayName': 'Renata Vallerio'}           4
# 3              {'displayName': 'Luis Fernando'}           5
# 4  {'displayName': 'Ana Paula Beltrão Machado'}           5
#
#                                              comment  \
# 0  (Translated by Google) Camping is pretty cool\...
# 1  (Translated by Google) Wonderful place to spen...
# 2                                                 Ok
# 3  (Translated by Google) Wonderful space and exp...
# 4  (Translated by Google) It's great for taking c...
#
#                  createTime                updateTime  \
# 0  2017-08-02T01:33:16.793Z  2017-08-02T01:33:16.793Z
# 1  2017-07-31T22:03:13.250Z  2017-07-31T22:03:13.250Z
# 2  2017-07-30T20:02:42.772Z  2017-07-30T20:02:42.772Z
# 3  2017-07-29T11:41:13.472Z  2017-07-29T11:41:40.938Z
# 4  2017-07-29T03:58:47.007Z  2017-07-29T04:00:17.528Z
#
#                                                 name  \
# 0  accounts/113838515205835963900/locations/41527...
# 1  accounts/113838515205835963900/locations/41527...
# 2  accounts/113838515205835963900/locations/41527...
# 3  accounts/113838515205835963900/locations/41527...
# 4  accounts/113838515205835963900/locations/41527...
#
#                  displayName              reviewer_name  \
# 0    Alessandro Filipe (Alê)    Alessandro Filipe (Alê)
# 1           Rilvana Pinheiro           Rilvana Pinheiro
# 2            Renata Vallerio            Renata Vallerio
# 3              Luis Fernando              Luis Fernando
# 4  Ana Paula Beltrão Machado  Ana Paula Beltrão Machado
#
#                               review_id reviewReply  \
# 0   ChZDSUhNMG9nS0VJQ0FnSURRekxMMFhnEAE         NaN
# 1   ChZDSUhNMG9nS0VJQ0FnSUNBMXBEOURnEAE         NaN
# 2  ChdDSUhNMG9nS0VJQ0FnSURBb3NHM25BRRAB         NaN
# 3  ChdDSUhNMG9nS0VJQ0FnSURnMzc2a2t3RRAB         NaN
# 4   ChZDSUhNMG9nS0VJQ0FnSUNRbUpXbUx3EAE         NaN
#
#                                      before_original after_original  \
# 0  (Translated by Google) Camping is pretty cool\...       Original
# 1  (Translated by Google) Wonderful place to spen...       Original
# 2                                                 Ok           None
# 3  (Translated by Google) Wonderful space and exp...       Original
# 4  (Translated by Google) It's great for taking c...       Original
#
#                                         cleaned_text
# 0                             Camping is pretty cool
# 1  Wonderful place to spend a day with the family...
# 2                                                 Ok
# 3         Wonderful space and experience with nature
# 4  It's great for taking children, it has water s...

# %%
f["cleaned_text"].iloc[1]
# Out:
# 'Wonderful place to spend a day with the family, maintained, organized, pleasant, clean environment'

# %%
f["after_original"].iloc[1]
# Out:
# 'Original'

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reviewer         268 non-null    object
#  1   starRating       268 non-null    int64
#  2   comment          268 non-null    object
#  3   createTime       268 non-null    object
#  4   updateTime       268 non-null    object
#  5   name             268 non-null    object
#  6   displayName      248 non-null    object
#  7   reviewer_name    248 non-null    object
#  8   review_id        248 non-null    object
#  9   reviewReply      46 non-null     object
#  10  before_original  268 non-null    object
#  11  after_original   164 non-null    object
#  12  cleaned_text     268 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 27.3+ KB

# %%
from textblob import TextBlob

# Assuming you have a DataFrame df with a column named 'cleaned_text'
mixed_language_text = f["cleaned_text"].str.cat(sep=' ')

blob = TextBlob(mixed_language_text)
sentiment = blob.sentiment

print(f"Sentiment: {sentiment.polarity}")
# Out:
# Sentiment: 0.48441585557694494

# %%
# Function to perform sentiment analysis
def analyze_sentiment(text):
    blob = TextBlob(text)
    sentiment = blob.sentiment
    return sentiment.polarity

# Add a new column 'Sentiment_Score' to the DataFrame
f['Sentiment_Score'] = f["cleaned_text"].apply(analyze_sentiment)

# %%
f.tail()
# Out:
#                                        reviewer  starRating  \
# 263    {'displayName': 'Cleber Gerber Mangini'}           5
# 264             {'displayName': 'Rosa Ferrari'}           5
# 265           {'displayName': 'Isabella Catto'}           5
# 266  {'displayName': 'Marilda Fatima da Silva'}           5
# 267         {'displayName': 'Giovanna Sanchez'}           5
#
#                                                comment  \
# 263                                                nan
# 264  (Translated by Google) I really enjoyed this p...
# 265                                                nan
# 266                                                nan
# 267                                                nan
#
#                       createTime                   updateTime  \
# 263  2018-11-16T23:07:01.174991Z  2018-11-16T23:07:01.174991Z
# 264  2018-11-16T21:20:03.059487Z  2018-11-16T21:20:03.059487Z
# 265  2018-11-16T21:12:33.298498Z  2018-11-16T21:12:33.298498Z
# 266  2018-11-16T20:32:39.223279Z  2018-11-16T20:32:39.223279Z
# 267  2018-11-15T20:19:37.060735Z  2018-11-15T20:19:37.060735Z
#
#                                                   name  \
# 263  accounts/113838515205835963900/locations/41527...
# 264  accounts/113838515205835963900/locations/41527...
# 265  accounts/113838515205835963900/locations/41527...
# 266  accounts/113838515205835963900/locations/41527...
# 267  accounts/113838515205835963900/locations/41527...
#
#                  displayName            reviewer_name  \
# 263    Cleber Gerber Mangini    Cleber Gerber Mangini
# 264             Rosa Ferrari             Rosa Ferrari
# 265           Isabella Catto           Isabella Catto
# 266  Marilda Fatima da Silva  Marilda Fatima da Silva
# 267         Giovanna Sanchez         Giovanna Sanchez
#
#                                 review_id reviewReply  \
# 263   ChZDSUhNMG9nS0VJQ0FnSUNJbnZtcUh3EAE         NaN
# 264   ChZDSUhNMG9nS0VJQ0FnSUNvNmQtRVl3EAE         NaN
# 265  ChdDSUhNMG9nS0VJQ0FnSUNJbnQ3anZ3RRAB         NaN
# 266   ChZDSUhNMG9nS0VJQ0FnSUNJbnZia0pREAE         NaN
# 267  ChdDSUhNMG9nS0VJQ0FnSUNJcnRISHd3RRAB         NaN
#
#                                        before_original after_original  \
# 263                                                nan           None
# 264  (Translated by Google) I really enjoyed this p...       Original
# 265                                                nan           None
# 266                                                nan           None
# 267                                                nan           None
#
#                       cleaned_text  Sentiment_Score
# 263                            nan          0.00000
# 264  I really enjoyed this place!!          0.78125
# 265                            nan          0.00000
# 266                            nan          0.00000
# 267                            nan          0.00000

# %%
# Assuming you have a DataFrame df
f.dropna(subset=['cleaned_text'], inplace=True)

# Display the DataFrame after dropping rows with missing values in 'cleaned_text'
f.head(2)
# Out:
#                                      reviewer  starRating  \
# 0  {'displayName': 'Alessandro Filipe (Alê)'}           5
# 1         {'displayName': 'Rilvana Pinheiro'}           5
#
#                                              comment  \
# 0  (Translated by Google) Camping is pretty cool\...
# 1  (Translated by Google) Wonderful place to spen...
#
#                  createTime                updateTime  \
# 0  2017-08-02T01:33:16.793Z  2017-08-02T01:33:16.793Z
# 1  2017-07-31T22:03:13.250Z  2017-07-31T22:03:13.250Z
#
#                                                 name              displayName  \
# 0  accounts/113838515205835963900/locations/41527...  Alessandro Filipe (Alê)
# 1  accounts/113838515205835963900/locations/41527...         Rilvana Pinheiro
#
#              reviewer_name                            review_id reviewReply  \
# 0  Alessandro Filipe (Alê)  ChZDSUhNMG9nS0VJQ0FnSURRekxMMFhnEAE         NaN
# 1         Rilvana Pinheiro  ChZDSUhNMG9nS0VJQ0FnSUNBMXBEOURnEAE         NaN
#
#                                      before_original after_original  \
# 0  (Translated by Google) Camping is pretty cool\...       Original
# 1  (Translated by Google) Wonderful place to spen...       Original
#
#                                         cleaned_text  Sentiment_Score
# 0                             Camping is pretty cool              0.3
# 1  Wonderful place to spend a day with the family...              0.7

# %%
import numpy as np

# Replace 'nan' with numpy.nan
f.replace('nan', np.nan, inplace=True)

# Now you can drop rows with NaN values
f.dropna(subset=['cleaned_text'], inplace=True)

# %%
# Display the DataFrame
f.head(2)
# Out:
#                                      reviewer  starRating  \
# 0  {'displayName': 'Alessandro Filipe (Alê)'}           5
# 1         {'displayName': 'Rilvana Pinheiro'}           5
#
#                                              comment  \
# 0  (Translated by Google) Camping is pretty cool\...
# 1  (Translated by Google) Wonderful place to spen...
#
#                  createTime                updateTime  \
# 0  2017-08-02T01:33:16.793Z  2017-08-02T01:33:16.793Z
# 1  2017-07-31T22:03:13.250Z  2017-07-31T22:03:13.250Z
#
#                                                 name              displayName  \
# 0  accounts/113838515205835963900/locations/41527...  Alessandro Filipe (Alê)
# 1  accounts/113838515205835963900/locations/41527...         Rilvana Pinheiro
#
#              reviewer_name                            review_id reviewReply  \
# 0  Alessandro Filipe (Alê)  ChZDSUhNMG9nS0VJQ0FnSURRekxMMFhnEAE         NaN
# 1         Rilvana Pinheiro  ChZDSUhNMG9nS0VJQ0FnSUNBMXBEOURnEAE         NaN
#
#                                      before_original after_original  \
# 0  (Translated by Google) Camping is pretty cool\...       Original
# 1  (Translated by Google) Wonderful place to spen...       Original
#
#                                         cleaned_text  Sentiment_Score
# 0                             Camping is pretty cool              0.3
# 1  Wonderful place to spend a day with the family...              0.7

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 168 entries, 0 to 264
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   reviewer         168 non-null    object
#  1   starRating       168 non-null    int64
#  2   comment          168 non-null    object
#  3   createTime       168 non-null    object
#  4   updateTime       168 non-null    object
#  5   name             168 non-null    object
#  6   displayName      159 non-null    object
#  7   reviewer_name    159 non-null    object
#  8   review_id        159 non-null    object
#  9   reviewReply      28 non-null     object
#  10  before_original  168 non-null    object
#  11  after_original   164 non-null    object
#  12  cleaned_text     168 non-null    object
#  13  Sentiment_Score  168 non-null    float64
# dtypes: float64(1), int64(1), object(12)
# memory usage: 19.7+ KB

# %%
import matplotlib.pyplot as plt

# Assuming you have a DataFrame 'f' with a column 'Sent_Sc_P'
# Create a histogram of sentiment scores
plt.hist(f['Sentiment_Score'], bins=20, edgecolor='black')
plt.xlabel('Sentiment Score')
plt.ylabel('Frequency')
plt.title('Distribution of Sentiment Scores')
plt.show()

# %%
ml = f[["starRating", "cleaned_text", "Sentiment_Score"]]

# %%
ml.head()
# Out:
#    starRating                                       cleaned_text  \
# 0           5                             Camping is pretty cool
# 1           5  Wonderful place to spend a day with the family...
# 2           4                                                 Ok
# 3           5         Wonderful space and experience with nature
# 4           5  It's great for taking children, it has water s...
#
#    Sentiment_Score
# 0              0.3
# 1              0.7
# 2              0.5
# 3              1.0
# 4              0.8

# %%
ml.loc[:, "word_count"] = ml["cleaned_text"].apply(lambda x: len(str(x).split(" ")))
# Out:
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/3453364577.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml.loc[:, "word_count"] = ml["cleaned_text"].apply(lambda x: len(str(x).split(" ")))

# %%
ml.tail()
# Out:
#      starRating                                       cleaned_text  \
# 257           5  Great environment for those looking for a hone...
# 258           4                                               Good
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count
# 257         0.312063          49
# 258         0.700000           1
# 259         0.250000           2
# 262         0.775000          13
# 264         0.781250           5

# %%
def avg_word(sentence):
  words = sentence.split()
  return (sum(len(word) for word in words)/len(words))

ml.loc[:, "avg_word"] = ml["cleaned_text"].apply(lambda x: avg_word(x))
# Out:
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/43500064.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml.loc[:, "avg_word"] = ml["cleaned_text"].apply(lambda x: avg_word(x))

# %%
ml.tail()
# Out:
#      starRating                                       cleaned_text  \
# 257           5  Great environment for those looking for a hone...
# 258           4                                               Good
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count  avg_word
# 257         0.312063          49  4.408163
# 258         0.700000           1  4.000000
# 259         0.250000           2  4.000000
# 262         0.775000          13  4.230769
# 264         0.781250           5  5.000000

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/izaiaszacca/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')

# %%
ml['stopwords'] = ml["cleaned_text"].apply(lambda x: len([word for word in str(x).split() if word in stop]) if isinstance(x, str) else 0)
# Out:
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/416350120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml['stopwords'] = ml["cleaned_text"].apply(lambda x: len([word for word in str(x).split() if word in stop]) if isinstance(x, str) else 0)

# %%
ml.tail()
# Out:
#      starRating                                       cleaned_text  \
# 257           5  Great environment for those looking for a hone...
# 258           4                                               Good
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count  avg_word  stopwords
# 257         0.312063          49  4.408163         21
# 258         0.700000           1  4.000000          0
# 259         0.250000           2  4.000000          0
# 262         0.775000          13  4.230769          6
# 264         0.781250           5  5.000000          1

# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')  # Download the stopwords dataset

stop = stopwords.words('english')  # Choose the language for stop words

# Function to remove stop words
def remove_stopwords(text):
    words = [word for word in text.split() if word.lower() not in stop]
    return ' '.join(words)

# Apply the function to your DataFrame
ml['no_stopwords'] = ml['cleaned_text'].apply(remove_stopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/izaiaszacca/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/4207867580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml['no_stopwords'] = ml['cleaned_text'].apply(remove_stopwords)

# %%
ml.tail()
# Out:
#      starRating                                       cleaned_text  \
# 257           5  Great environment for those looking for a hone...
# 258           4                                               Good
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count  avg_word  stopwords  \
# 257         0.312063          49  4.408163         21
# 258         0.700000           1  4.000000          0
# 259         0.250000           2  4.000000          0
# 262         0.775000          13  4.230769          6
# 264         0.781250           5  5.000000          1
#
#                                           no_stopwords
# 257  Great environment looking honeymoon trip famil...
# 258                                               Good
# 259                                              much!
# 262             beautiful place nature good pools food
# 264                             really enjoyed place!!

# %%
ml["lower"] = ml["no_stopwords"].str.lower()
# Out:
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/3899530020.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml["lower"] = ml["no_stopwords"].str.lower()

# %%
ml.tail()
# Out:
#      starRating                                       cleaned_text  \
# 257           5  Great environment for those looking for a hone...
# 258           4                                               Good
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count  avg_word  stopwords  \
# 257         0.312063          49  4.408163         21
# 258         0.700000           1  4.000000          0
# 259         0.250000           2  4.000000          0
# 262         0.775000          13  4.230769          6
# 264         0.781250           5  5.000000          1
#
#                                           no_stopwords  \
# 257  Great environment looking honeymoon trip famil...
# 258                                               Good
# 259                                              much!
# 262             beautiful place nature good pools food
# 264                             really enjoyed place!!
#
#                                                  lower
# 257  great environment looking honeymoon trip famil...
# 258                                               good
# 259                                              much!
# 262             beautiful place nature good pools food
# 264                             really enjoyed place!!

# %%
import re

# Assuming your DataFrame is named 'ml' with a column 'cleaned_text_lower'
ml['no_punct'] = ml['lower'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)
# Out:
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/883313916.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml['no_punct'] = ml['lower'].str.replace(r'[^a-zA-Z0-9\s]', '', regex=True)

# %%
ml.tail(3)
# Out:
#      starRating                                       cleaned_text  \
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count  avg_word  stopwords  \
# 259          0.25000           2  4.000000          0
# 262          0.77500          13  4.230769          6
# 264          0.78125           5  5.000000          1
#
#                                no_stopwords  \
# 259                                   much!
# 262  beautiful place nature good pools food
# 264                  really enjoyed place!!
#
#                                       lower  \
# 259                                   much!
# 262  beautiful place nature good pools food
# 264                  really enjoyed place!!
#
#                                    no_punct
# 259                                    much
# 262  beautiful place nature good pools food
# 264                    really enjoyed place

# %%
import emoji

# Assuming 'no_punct' is the column with text containing emojis
ml['no_emojis'] = ml['no_punct'].apply(lambda x: emoji.demojize(x))

# Now 'no_emojis' column will contain text with emojis replaced by their names
# Out:
# /var/folders/0_/23jph36d0154h_0z_b1ppjfw0000gn/T/ipykernel_3511/2406122718.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ml['no_emojis'] = ml['no_punct'].apply(lambda x: emoji.demojize(x))

# %%
ml.tail(3)
# Out:
#      starRating                                       cleaned_text  \
# 259           5                                          Too much!
# 262           5  There is a beautiful place into the nature wit...
# 264           5                      I really enjoyed this place!!
#
#      Sentiment_Score  word_count  avg_word  stopwords  \
# 259          0.25000           2  4.000000          0
# 262          0.77500          13  4.230769          6
# 264          0.78125           5  5.000000          1
#
#                                no_stopwords  \
# 259                                   much!
# 262  beautiful place nature good pools food
# 264                  really enjoyed place!!
#
#                                       lower  \
# 259                                   much!
# 262  beautiful place nature good pools food
# 264                  really enjoyed place!!
#
#                                    no_punct  \
# 259                                    much
# 262  beautiful place nature good pools food
# 264                    really enjoyed place
#
#                                   no_emojis
# 259                                    much
# 262  beautiful place nature good pools food
# 264                    really enjoyed place

# %%
sns.pairplot(ml[["starRating", "Sentiment_Score"]])
# Out:
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/izaiaszacca/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# MAYBE I SHOULD DO THE SENTIMENT ANALYSIS AFTER THE CLEANING
#
# I WILL DO IT TOMORROW
